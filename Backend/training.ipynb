# %%
import cv2
import os

def extract_frames_from_videos(video_folder, output_folder, label):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    video_files = [f for f in os.listdir(video_folder) if f.endswith('.mp4')]
    
    for video_file in video_files:
        video_path = os.path.join(video_folder, video_file)
        video_name = os.path.splitext(video_file)[0]
        video_output_folder = os.path.join(output_folder, label, video_name)
        
        if not os.path.exists(video_output_folder):
            os.makedirs(video_output_folder)
        
        # Check if frames are already extracted
        if len(os.listdir(video_output_folder)) > 0:
            print(f"Frames already extracted for {video_file}")
            continue
        
        cap = cv2.VideoCapture(video_path)
        frame_count = 0

        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            frame_path = os.path.join(video_output_folder, f"{label}_frame_{frame_count}.jpg")
            cv2.imwrite(frame_path, frame)
            frame_count += 1

        cap.release()
        print(f"Extracted {frame_count} frames from {video_file}")

# Extract frames for each class
extract_frames_from_videos("Dataset/Climb", "ExtractedFrames", "Climb")
extract_frames_from_videos("Dataset/Jump", "ExtractedFrames", "Jump")
extract_frames_from_videos("Dataset/Normal", "ExtractedFrames", "Normal")
# Out:
# Frames already extracted for 1.mp4
# Frames already extracted for 10.mp4
# Frames already extracted for 100.mp4
# Frames already extracted for 101.mp4
# Frames already extracted for 102.mp4
# Frames already extracted for 103.mp4
# Frames already extracted for 104.mp4
# Frames already extracted for 105.mp4
# Frames already extracted for 106.mp4
# Frames already extracted for 107.mp4
# Frames already extracted for 108.mp4
# Frames already extracted for 109.mp4
# Frames already extracted for 11.mp4
# Frames already extracted for 110.mp4
# Frames already extracted for 111.mp4
# Frames already extracted for 112.mp4
# Frames already extracted for 113.mp4
# Frames already extracted for 114.mp4
# Frames already extracted for 115.mp4
# Frames already extracted for 116.mp4
# Frames already extracted for 117.mp4
# Frames already extracted for 118.mp4
# Frames already extracted for 119.mp4
# Frames already extracted for 12.mp4
# Frames already extracted for 120.mp4
# Frames already extracted for 13.mp4
# Frames already extracted for 14.mp4
# Frames already extracted for 15.mp4
# Frames already extracted for 16.mp4
# Frames already extracted for 17.mp4
# Frames already extracted for 18.mp4
# Frames already extracted for 19.mp4
# Frames already extracted for 2.mp4
# Frames already extracted for 20.mp4
# Frames already extracted for 21.mp4
# Frames already extracted for 22.mp4
# Frames already extracted for 23.mp4
# Frames already extracted for 24.mp4
# Frames already extracted for 25.mp4
# Frames already extracted for 26.mp4
# Frames already extracted for 27.mp4
# Frames already extracted for 28.mp4
# Frames already extracted for 29.mp4
# Frames already extracted for 3.mp4
# Frames already extracted for 30.mp4
# Frames already extracted for 31.mp4
# Frames already extracted for 32.mp4
# Frames already extracted for 33.mp4
# Frames already extracted for 34.mp4
# Frames already extracted for 35.mp4
# Frames already extracted for 36.mp4
# Frames already extracted for 37.mp4
# Frames already extracted for 38.mp4
# Frames already extracted for 39.mp4
# Frames already extracted for 4.mp4
# Frames already extracted for 40.mp4
# Frames already extracted for 41.mp4
# Frames already extracted for 42.mp4
# Frames already extracted for 43.mp4
# Frames already extracted for 44.mp4
# Frames already extracted for 45.mp4
# Frames already extracted for 46.mp4
# Frames already extracted for 47.mp4
# Frames already extracted for 48.mp4
# Frames already extracted for 49.mp4
# Frames already extracted for 5.mp4
# Frames already extracted for 50.mp4
# Frames already extracted for 51.mp4
# Frames already extracted for 52.mp4
# Frames already extracted for 53.mp4
# Frames already extracted for 54.mp4
# Frames already extracted for 55.mp4
# Frames already extracted for 56.mp4
# Frames already extracted for 57.mp4
# Frames already extracted for 58.mp4
# Frames already extracted for 59.mp4
# Frames already extracted for 6.mp4
# Frames already extracted for 60.mp4
# Frames already extracted for 61.mp4
# Frames already extracted for 62.mp4
# Frames already extracted for 63.mp4
# Frames already extracted for 64.mp4
# Frames already extracted for 65.mp4
# Frames already extracted for 66.mp4
# Frames already extracted for 67.mp4
# Frames already extracted for 68.mp4
# Frames already extracted for 69.mp4
# Frames already extracted for 7.mp4
# Frames already extracted for 70.mp4
# Frames already extracted for 71.mp4
# Frames already extracted for 72.mp4
# Frames already extracted for 73.mp4
# Frames already extracted for 74.mp4
# Frames already extracted for 75.mp4
# Frames already extracted for 76.mp4
# Frames already extracted for 77.mp4
# Frames already extracted for 78.mp4
# Frames already extracted for 79.mp4
# Frames already extracted for 8.mp4
# Frames already extracted for 80.mp4
# Frames already extracted for 81.mp4
# Frames already extracted for 82.mp4
# Frames already extracted for 83.mp4
# Frames already extracted for 84.mp4
# Frames already extracted for 85.mp4
# Frames already extracted for 86.mp4
# Frames already extracted for 87.mp4
# Frames already extracted for 88.mp4
# Frames already extracted for 89.mp4
# Frames already extracted for 9.mp4
# Frames already extracted for 90.mp4
# Frames already extracted for 91.mp4
# Frames already extracted for 92.mp4
# Frames already extracted for 93.mp4
# Frames already extracted for 94.mp4
# Frames already extracted for 95.mp4
# Frames already extracted for 96.mp4
# Frames already extracted for 97.mp4
# Frames already extracted for 98.mp4
# Frames already extracted for 99.mp4
# Frames already extracted for 1.mp4
# Frames already extracted for 10.mp4
# Frames already extracted for 11.mp4
# Frames already extracted for 12.mp4
# Frames already extracted for 13.mp4
# Frames already extracted for 14.mp4
# Frames already extracted for 15.mp4
# Frames already extracted for 16.mp4
# Frames already extracted for 17.mp4
# Frames already extracted for 18.mp4
# Frames already extracted for 19.mp4
# Frames already extracted for 2.mp4
# Frames already extracted for 20.mp4
# Frames already extracted for 21.mp4
# Frames already extracted for 22.mp4
# Frames already extracted for 23.mp4
# Frames already extracted for 24.mp4
# Frames already extracted for 25.mp4
# Frames already extracted for 26.mp4
# Frames already extracted for 27.mp4
# Frames already extracted for 28.mp4
# Frames already extracted for 29.mp4
# Frames already extracted for 3.mp4
# Frames already extracted for 30.mp4
# Frames already extracted for 31.mp4
# Frames already extracted for 32.mp4
# Frames already extracted for 33.mp4
# Frames already extracted for 34.mp4
# Frames already extracted for 35.mp4
# Frames already extracted for 36.mp4
# Frames already extracted for 37.mp4
# Frames already extracted for 38.mp4
# Frames already extracted for 39.mp4
# Frames already extracted for 4.mp4
# Frames already extracted for 40.mp4
# Frames already extracted for 41.mp4
# Frames already extracted for 42.mp4
# Frames already extracted for 43.mp4
# Frames already extracted for 44.mp4
# Frames already extracted for 45.mp4
# Frames already extracted for 46.mp4
# Frames already extracted for 47.mp4
# Frames already extracted for 48.mp4
# Frames already extracted for 49.mp4
# Frames already extracted for 5.mp4
# Frames already extracted for 50.mp4
# Frames already extracted for 51.mp4
# Frames already extracted for 52.mp4
# Frames already extracted for 53.mp4
# Frames already extracted for 54.mp4
# Frames already extracted for 55.mp4
# Frames already extracted for 56.mp4
# Frames already extracted for 57.mp4
# Frames already extracted for 58.mp4
# Frames already extracted for 59.mp4
# Frames already extracted for 6.mp4
# Frames already extracted for 60.mp4
# Frames already extracted for 61.mp4
# Frames already extracted for 62.mp4
# Frames already extracted for 63.mp4
# Frames already extracted for 64.mp4
# Frames already extracted for 65.mp4
# Frames already extracted for 66.mp4
# Frames already extracted for 67.mp4
# Frames already extracted for 68.mp4
# Frames already extracted for 69.mp4
# Frames already extracted for 7.mp4
# Frames already extracted for 70.mp4
# Frames already extracted for 71.mp4
# Frames already extracted for 72.mp4
# Frames already extracted for 73.mp4
# Frames already extracted for 74.mp4
# Frames already extracted for 75.mp4
# Frames already extracted for 76.mp4
# Frames already extracted for 77.mp4
# Frames already extracted for 78.mp4
# Frames already extracted for 79.mp4
# Frames already extracted for 8.mp4
# Frames already extracted for 80.mp4
# Frames already extracted for 81.mp4
# Frames already extracted for 82.mp4
# Frames already extracted for 83.mp4
# Frames already extracted for 84.mp4
# Frames already extracted for 85.mp4
# Frames already extracted for 86.mp4
# Frames already extracted for 87.mp4
# Frames already extracted for 88.mp4
# Frames already extracted for 89.mp4
# Frames already extracted for 9.mp4
# Frames already extracted for 90.mp4
# Frames already extracted for 91.mp4
# Frames already extracted for 92.mp4
# Frames already extracted for 93.mp4
# Frames already extracted for 94.mp4
# Frames already extracted for 95.mp4
# Frames already extracted for 96.mp4
# Frames already extracted for 97.mp4
# Frames already extracted for 98.mp4
# Frames already extracted for 1.mp4
# Frames already extracted for 10.mp4
# Frames already extracted for 100.mp4
# Frames already extracted for 101.mp4
# Frames already extracted for 102.mp4
# Frames already extracted for 103.mp4
# Frames already extracted for 104.mp4
# Frames already extracted for 105.mp4
# Frames already extracted for 106.mp4
# Frames already extracted for 107.mp4
# Frames already extracted for 108.mp4
# Frames already extracted for 109.mp4
# Frames already extracted for 11.mp4
# Frames already extracted for 110.mp4
# Frames already extracted for 111.mp4
# Frames already extracted for 112.mp4
# Frames already extracted for 113.mp4
# Frames already extracted for 114.mp4
# Frames already extracted for 115.mp4
# Frames already extracted for 12.mp4
# Frames already extracted for 13.mp4
# Frames already extracted for 14.mp4
# Frames already extracted for 15.mp4
# Frames already extracted for 16.mp4
# Frames already extracted for 17.mp4
# Frames already extracted for 18.mp4
# Frames already extracted for 19.mp4
# Frames already extracted for 2.mp4
# Frames already extracted for 20.mp4
# Frames already extracted for 21.mp4
# Frames already extracted for 22.mp4
# Frames already extracted for 23.mp4
# Frames already extracted for 24.mp4
# Frames already extracted for 25.mp4
# Frames already extracted for 26.mp4
# Frames already extracted for 27.mp4
# Frames already extracted for 28.mp4
# Frames already extracted for 29.mp4
# Frames already extracted for 3.mp4
# Frames already extracted for 30.mp4
# Frames already extracted for 31.mp4
# Frames already extracted for 32.mp4
# Frames already extracted for 33.mp4
# Frames already extracted for 34.mp4
# Frames already extracted for 35.mp4
# Frames already extracted for 36.mp4
# Frames already extracted for 37.mp4
# Frames already extracted for 38.mp4
# Frames already extracted for 39.mp4
# Frames already extracted for 4.mp4
# Frames already extracted for 40.mp4
# Frames already extracted for 41.mp4
# Frames already extracted for 42.mp4
# Frames already extracted for 43.mp4
# Frames already extracted for 44.mp4
# Frames already extracted for 45.mp4
# Frames already extracted for 46.mp4
# Frames already extracted for 47.mp4
# Frames already extracted for 48.mp4
# Frames already extracted for 49.mp4
# Frames already extracted for 5.mp4
# Frames already extracted for 50.mp4
# Frames already extracted for 51.mp4
# Frames already extracted for 52.mp4
# Frames already extracted for 53.mp4
# Frames already extracted for 54.mp4
# Frames already extracted for 55.mp4
# Frames already extracted for 56.mp4
# Frames already extracted for 57.mp4
# Frames already extracted for 58.mp4
# Frames already extracted for 59.mp4
# Frames already extracted for 6.mp4
# Frames already extracted for 60.mp4
# Frames already extracted for 61.mp4
# Frames already extracted for 62.mp4
# Frames already extracted for 63.mp4
# Frames already extracted for 64.mp4
# Frames already extracted for 65.mp4
# Frames already extracted for 66.mp4
# Frames already extracted for 67.mp4
# Frames already extracted for 68.mp4
# Frames already extracted for 69.mp4
# Frames already extracted for 7.mp4
# Frames already extracted for 70.mp4
# Frames already extracted for 71.mp4
# Frames already extracted for 72.mp4
# Frames already extracted for 73.mp4
# Frames already extracted for 74.mp4
# Frames already extracted for 75.mp4
# Frames already extracted for 76.mp4
# Frames already extracted for 77.mp4
# Frames already extracted for 78.mp4
# Frames already extracted for 79.mp4
# Frames already extracted for 8.mp4
# Frames already extracted for 80.mp4
# Frames already extracted for 81.mp4
# Frames already extracted for 82.mp4
# Frames already extracted for 83.mp4
# Frames already extracted for 84.mp4
# Frames already extracted for 85.mp4
# Frames already extracted for 86.mp4
# Frames already extracted for 87.mp4
# Frames already extracted for 88.mp4
# Frames already extracted for 89.mp4
# Frames already extracted for 9.mp4
# Frames already extracted for 90.mp4
# Frames already extracted for 91.mp4
# Frames already extracted for 92.mp4
# Frames already extracted for 93.mp4
# Frames already extracted for 94.mp4
# Frames already extracted for 95.mp4
# Frames already extracted for 96.mp4
# Frames already extracted for 97.mp4
# Frames already extracted for 98.mp4
# Frames already extracted for 99.mp4

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import img_to_array, load_img
import os

def load_frames_from_folder(folder, img_size=(64, 64)):
    frames = []
    labels = []
    for class_folder in os.listdir(folder):
        class_folder_path = os.path.join(folder, class_folder)
        if os.path.isdir(class_folder_path):
            for video_folder in os.listdir(class_folder_path):
                video_folder_path = os.path.join(class_folder_path, video_folder)
                if os.path.isdir(video_folder_path):
                    for filename in os.listdir(video_folder_path):
                        if filename.endswith(".jpg"):
                            img_path = os.path.join(video_folder_path, filename)
                            try:
                                img = load_img(img_path, target_size=img_size)
                                img_array = img_to_array(img)
                                frames.append(img_array)
                                if 'Climb' in class_folder:
                                    labels.append(0)
                                elif 'Jump' in class_folder:
                                    labels.append(1)
                                elif 'Normal' in class_folder:
                                    labels.append(2)
                                else:
                                    print(f"Unknown class folder: {class_folder}")
                            except Exception as e:
                                print(f"Error loading image {img_path}: {e}")
    return np.array(frames), np.array(labels)

# Load frames and labels for all classes
frames, labels = load_frames_from_folder("ExtractedFrames")

# Print the number of frames loaded for each class
print(f"Total frames: {len(frames)}, Total labels: {len(labels)}")

# Combine and normalize
frames = frames / 255.0

# Print the number of combined frames and labels
print(f"Total frames: {len(frames)}, Total labels: {len(labels)}")
# Out:
# Total frames: 52206, Total labels: 52206
# Total frames: 52206, Total labels: 52206

# %%
import numpy as np
from tensorflow.keras.utils import Sequence

class DataGenerator(Sequence):
    def __init__(self, frames, labels, batch_size=32, seq_length=20, img_size=(64, 64, 3), shuffle=True):
        self.frames = frames
        self.labels = labels
        self.batch_size = batch_size
        self.seq_length = seq_length
        self.img_size = img_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(self.labels) - self.seq_length + 1)
        self.on_epoch_end()
    
    def __len__(self):
        return int(np.floor((len(self.labels) - self.seq_length + 1) / self.batch_size))
    
    def __getitem__(self, index):
        indexes = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]
        X, y = self.__data_generation(indexes)
        return X, y
    
    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indexes)
    
    def __data_generation(self, indexes):
        X = np.empty((self.batch_size, self.seq_length, *self.img_size))
        y = np.empty((self.batch_size), dtype=int)
        
        for i, idx in enumerate(indexes):
            X[i,] = self.frames[idx:idx + self.seq_length]
            y[i] = self.labels[idx + self.seq_length - 1]
        
        return X, y

# Create the data generators
training_generator = DataGenerator(frames, labels, batch_size=32)
validation_generator = DataGenerator(frames, labels, batch_size=32)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, TimeDistributed, Flatten, LSTM, Dense

def create_lrcn_model(input_shape):
    model = Sequential()
    
    # 2D CNN within TimeDistributed
    model.add(TimeDistributed(Conv2D(64, (3, 3), activation='relu'), input_shape=input_shape))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(TimeDistributed(Flatten()))
    
    # LSTM
    model.add(LSTM(100))
    
    # Dense Layer
    model.add(Dense(3, activation='softmax'))
    
    return model

# Define the input shape
input_shape = (20, 64, 64, 3)

# Create the model
model = create_lrcn_model(input_shape)

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 20, 62, 62, 64)   1792
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 20, 31, 31, 64)   0
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 20, 61504)        0
#  tributed)
#
#  lstm (LSTM)                 (None, 100)               24642000
#
#  dense (Dense)               (None, 3)                 303
#
# =================================================================
# Total params: 24,644,095
# Trainable params: 24,644,095
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model using the generators
model.fit(training_generator, validation_data=validation_generator, epochs=5)

# Save the model
model.save('lrcn_model.h5')
# Out:
# Epoch 1/5
# 1630/1630 [==============================] - 2184s 1s/step - loss: 0.1170 - accuracy: 0.9588 - val_loss: 6.5303e-04 - val_accuracy: 1.0000
# Epoch 2/5
# 1630/1630 [==============================] - 2200s 1s/step - loss: 3.2268e-04 - accuracy: 1.0000 - val_loss: 1.3738e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 1630/1630 [==============================] - 2179s 1s/step - loss: 0.0065 - accuracy: 0.9980 - val_loss: 1.7952e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 1630/1630 [==============================] - 2199s 1s/step - loss: 0.0199 - accuracy: 0.9951 - val_loss: 9.0988e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 1630/1630 [==============================] - 2223s 1s/step - loss: 3.5230e-04 - accuracy: 1.0000 - val_loss: 1.1243e-04 - val_accuracy: 1.0000

# %%
from tensorflow.keras.models import load_model

# Load the saved model
model = load_model('lrcn_model.h5')

# %%
import cv2
import numpy as np
import os

def video_to_frames(video_path, img_size=(64, 64)):
    frames = []
    cap = cv2.VideoCapture(video_path)
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frame = cv2.resize(frame, img_size)
        frames.append(frame)
    cap.release()
    return np.array(frames)

# Example usage
test_video_path = 'Test\Test2.mp4'
test_frames = video_to_frames(test_video_path)
print(f"Extracted {test_frames.shape[0]} frames from the test video.")
# Out:
# Extracted 634 frames from the test video.

# %%
def preprocess_frames(frames, seq_length=20):
    frames = frames / 255.0  # Normalize the frames
    sequences = []
    for i in range(len(frames) - seq_length + 1):
        sequences.append(frames[i:i + seq_length])
    return np.array(sequences)

# Example usage
seq_length = 20
test_sequences = preprocess_frames(test_frames, seq_length)
print(f"Created {test_sequences.shape[0]} sequences from the test frames.")
# Out:
# Created 615 sequences from the test frames.

# %%
def predict_actions(sequences, model):
    predictions = model.predict(sequences)
    predicted_classes = np.argmax(predictions, axis=1)
    actions = {0: 'Climb', 1: 'Jump', 2: 'Normal'}
    predicted_actions = [actions[pred] for pred in predicted_classes]
    return predicted_actions

# Example usage
predicted_actions = predict_actions(test_sequences, model)
for i, action in enumerate(predicted_actions):
    print(f"Sequence {i}: Predicted Action: {action}")
# Out:
# 20/20 [==============================] - 5s 241ms/step
# Sequence 0: Predicted Action: Normal
# Sequence 1: Predicted Action: Normal
# Sequence 2: Predicted Action: Normal
# Sequence 3: Predicted Action: Normal
# Sequence 4: Predicted Action: Normal
# Sequence 5: Predicted Action: Normal
# Sequence 6: Predicted Action: Normal
# Sequence 7: Predicted Action: Normal
# Sequence 8: Predicted Action: Normal
# Sequence 9: Predicted Action: Normal
# Sequence 10: Predicted Action: Normal
# Sequence 11: Predicted Action: Normal
# Sequence 12: Predicted Action: Normal
# Sequence 13: Predicted Action: Normal
# Sequence 14: Predicted Action: Normal
# Sequence 15: Predicted Action: Normal
# Sequence 16: Predicted Action: Normal
# Sequence 17: Predicted Action: Normal
# Sequence 18: Predicted Action: Normal
# Sequence 19: Predicted Action: Normal
# Sequence 20: Predicted Action: Normal
# Sequence 21: Predicted Action: Normal
# Sequence 22: Predicted Action: Normal
# Sequence 23: Predicted Action: Normal
# Sequence 24: Predicted Action: Normal
# Sequence 25: Predicted Action: Normal
# Sequence 26: Predicted Action: Normal
# Sequence 27: Predicted Action: Normal
# Sequence 28: Predicted Action: Normal
# Sequence 29: Predicted Action: Normal
# Sequence 30: Predicted Action: Normal
# Sequence 31: Predicted Action: Normal
# Sequence 32: Predicted Action: Normal
# Sequence 33: Predicted Action: Normal
# Sequence 34: Predicted Action: Normal
# Sequence 35: Predicted Action: Normal
# Sequence 36: Predicted Action: Normal
# Sequence 37: Predicted Action: Normal
# Sequence 38: Predicted Action: Normal
# Sequence 39: Predicted Action: Normal
# Sequence 40: Predicted Action: Normal
# Sequence 41: Predicted Action: Normal
# Sequence 42: Predicted Action: Normal
# Sequence 43: Predicted Action: Normal
# Sequence 44: Predicted Action: Normal
# Sequence 45: Predicted Action: Normal
# Sequence 46: Predicted Action: Normal
# Sequence 47: Predicted Action: Normal
# Sequence 48: Predicted Action: Normal
# Sequence 49: Predicted Action: Normal
# Sequence 50: Predicted Action: Normal
# Sequence 51: Predicted Action: Normal
# Sequence 52: Predicted Action: Normal
# Sequence 53: Predicted Action: Normal
# Sequence 54: Predicted Action: Normal
# Sequence 55: Predicted Action: Normal
# Sequence 56: Predicted Action: Normal
# Sequence 57: Predicted Action: Normal
# Sequence 58: Predicted Action: Normal
# Sequence 59: Predicted Action: Normal
# Sequence 60: Predicted Action: Normal
# Sequence 61: Predicted Action: Normal
# Sequence 62: Predicted Action: Normal
# Sequence 63: Predicted Action: Normal
# Sequence 64: Predicted Action: Normal
# Sequence 65: Predicted Action: Normal
# Sequence 66: Predicted Action: Normal
# Sequence 67: Predicted Action: Normal
# Sequence 68: Predicted Action: Normal
# Sequence 69: Predicted Action: Normal
# Sequence 70: Predicted Action: Normal
# Sequence 71: Predicted Action: Normal
# Sequence 72: Predicted Action: Normal
# Sequence 73: Predicted Action: Normal
# Sequence 74: Predicted Action: Normal
# Sequence 75: Predicted Action: Normal
# Sequence 76: Predicted Action: Normal
# Sequence 77: Predicted Action: Normal
# Sequence 78: Predicted Action: Normal
# Sequence 79: Predicted Action: Normal
# Sequence 80: Predicted Action: Normal
# Sequence 81: Predicted Action: Normal
# Sequence 82: Predicted Action: Normal
# Sequence 83: Predicted Action: Normal
# Sequence 84: Predicted Action: Normal
# Sequence 85: Predicted Action: Normal
# Sequence 86: Predicted Action: Normal
# Sequence 87: Predicted Action: Normal
# Sequence 88: Predicted Action: Normal
# Sequence 89: Predicted Action: Normal
# Sequence 90: Predicted Action: Normal
# Sequence 91: Predicted Action: Normal
# Sequence 92: Predicted Action: Normal
# Sequence 93: Predicted Action: Normal
# Sequence 94: Predicted Action: Normal
# Sequence 95: Predicted Action: Normal
# Sequence 96: Predicted Action: Normal
# Sequence 97: Predicted Action: Normal
# Sequence 98: Predicted Action: Normal
# Sequence 99: Predicted Action: Normal
# Sequence 100: Predicted Action: Normal
# Sequence 101: Predicted Action: Normal
# Sequence 102: Predicted Action: Normal
# Sequence 103: Predicted Action: Normal
# Sequence 104: Predicted Action: Normal
# Sequence 105: Predicted Action: Normal
# Sequence 106: Predicted Action: Normal
# Sequence 107: Predicted Action: Normal
# Sequence 108: Predicted Action: Normal
# Sequence 109: Predicted Action: Normal
# Sequence 110: Predicted Action: Normal
# Sequence 111: Predicted Action: Normal
# Sequence 112: Predicted Action: Normal
# Sequence 113: Predicted Action: Normal
# Sequence 114: Predicted Action: Normal
# Sequence 115: Predicted Action: Normal
# Sequence 116: Predicted Action: Normal
# Sequence 117: Predicted Action: Normal
# Sequence 118: Predicted Action: Normal
# Sequence 119: Predicted Action: Normal
# Sequence 120: Predicted Action: Normal
# Sequence 121: Predicted Action: Normal
# Sequence 122: Predicted Action: Normal
# Sequence 123: Predicted Action: Normal
# Sequence 124: Predicted Action: Normal
# Sequence 125: Predicted Action: Normal
# Sequence 126: Predicted Action: Normal
# Sequence 127: Predicted Action: Normal
# Sequence 128: Predicted Action: Normal
# Sequence 129: Predicted Action: Normal
# Sequence 130: Predicted Action: Normal
# Sequence 131: Predicted Action: Normal
# Sequence 132: Predicted Action: Normal
# Sequence 133: Predicted Action: Normal
# Sequence 134: Predicted Action: Normal
# Sequence 135: Predicted Action: Normal
# Sequence 136: Predicted Action: Normal
# Sequence 137: Predicted Action: Normal
# Sequence 138: Predicted Action: Normal
# Sequence 139: Predicted Action: Normal
# Sequence 140: Predicted Action: Normal
# Sequence 141: Predicted Action: Normal
# Sequence 142: Predicted Action: Normal
# Sequence 143: Predicted Action: Normal
# Sequence 144: Predicted Action: Normal
# Sequence 145: Predicted Action: Normal
# Sequence 146: Predicted Action: Normal
# Sequence 147: Predicted Action: Normal
# Sequence 148: Predicted Action: Normal
# Sequence 149: Predicted Action: Normal
# Sequence 150: Predicted Action: Normal
# Sequence 151: Predicted Action: Normal
# Sequence 152: Predicted Action: Normal
# Sequence 153: Predicted Action: Normal
# Sequence 154: Predicted Action: Normal
# Sequence 155: Predicted Action: Normal
# Sequence 156: Predicted Action: Normal
# Sequence 157: Predicted Action: Normal
# Sequence 158: Predicted Action: Normal
# Sequence 159: Predicted Action: Normal
# Sequence 160: Predicted Action: Normal
# Sequence 161: Predicted Action: Normal
# Sequence 162: Predicted Action: Normal
# Sequence 163: Predicted Action: Normal
# Sequence 164: Predicted Action: Normal
# Sequence 165: Predicted Action: Normal
# Sequence 166: Predicted Action: Normal
# Sequence 167: Predicted Action: Normal
# Sequence 168: Predicted Action: Normal
# Sequence 169: Predicted Action: Normal
# Sequence 170: Predicted Action: Normal
# Sequence 171: Predicted Action: Normal
# Sequence 172: Predicted Action: Normal
# Sequence 173: Predicted Action: Normal
# Sequence 174: Predicted Action: Normal
# Sequence 175: Predicted Action: Normal
# Sequence 176: Predicted Action: Normal
# Sequence 177: Predicted Action: Normal
# Sequence 178: Predicted Action: Normal
# Sequence 179: Predicted Action: Normal
# Sequence 180: Predicted Action: Normal
# Sequence 181: Predicted Action: Normal
# Sequence 182: Predicted Action: Normal
# Sequence 183: Predicted Action: Normal
# Sequence 184: Predicted Action: Normal
# Sequence 185: Predicted Action: Normal
# Sequence 186: Predicted Action: Normal
# Sequence 187: Predicted Action: Normal
# Sequence 188: Predicted Action: Normal
# Sequence 189: Predicted Action: Normal
# Sequence 190: Predicted Action: Normal
# Sequence 191: Predicted Action: Normal
# Sequence 192: Predicted Action: Normal
# Sequence 193: Predicted Action: Normal
# Sequence 194: Predicted Action: Normal
# Sequence 195: Predicted Action: Normal
# Sequence 196: Predicted Action: Normal
# Sequence 197: Predicted Action: Normal
# Sequence 198: Predicted Action: Normal
# Sequence 199: Predicted Action: Normal
# Sequence 200: Predicted Action: Normal
# Sequence 201: Predicted Action: Normal
# Sequence 202: Predicted Action: Normal
# Sequence 203: Predicted Action: Normal
# Sequence 204: Predicted Action: Normal
# Sequence 205: Predicted Action: Normal
# Sequence 206: Predicted Action: Normal
# Sequence 207: Predicted Action: Normal
# Sequence 208: Predicted Action: Normal
# Sequence 209: Predicted Action: Normal
# Sequence 210: Predicted Action: Normal
# Sequence 211: Predicted Action: Normal
# Sequence 212: Predicted Action: Normal
# Sequence 213: Predicted Action: Normal
# Sequence 214: Predicted Action: Normal
# Sequence 215: Predicted Action: Normal
# Sequence 216: Predicted Action: Normal
# Sequence 217: Predicted Action: Normal
# Sequence 218: Predicted Action: Normal
# Sequence 219: Predicted Action: Normal
# Sequence 220: Predicted Action: Normal
# Sequence 221: Predicted Action: Normal
# Sequence 222: Predicted Action: Normal
# Sequence 223: Predicted Action: Normal
# Sequence 224: Predicted Action: Normal
# Sequence 225: Predicted Action: Normal
# Sequence 226: Predicted Action: Normal
# Sequence 227: Predicted Action: Normal
# Sequence 228: Predicted Action: Normal
# Sequence 229: Predicted Action: Normal
# Sequence 230: Predicted Action: Normal
# Sequence 231: Predicted Action: Normal
# Sequence 232: Predicted Action: Normal
# Sequence 233: Predicted Action: Normal
# Sequence 234: Predicted Action: Normal
# Sequence 235: Predicted Action: Normal
# Sequence 236: Predicted Action: Normal
# Sequence 237: Predicted Action: Normal
# Sequence 238: Predicted Action: Normal
# Sequence 239: Predicted Action: Normal
# Sequence 240: Predicted Action: Normal
# Sequence 241: Predicted Action: Normal
# Sequence 242: Predicted Action: Normal
# Sequence 243: Predicted Action: Normal
# Sequence 244: Predicted Action: Normal
# Sequence 245: Predicted Action: Normal
# Sequence 246: Predicted Action: Normal
# Sequence 247: Predicted Action: Normal
# Sequence 248: Predicted Action: Climb
# Sequence 249: Predicted Action: Climb
# Sequence 250: Predicted Action: Climb
# Sequence 251: Predicted Action: Climb
# Sequence 252: Predicted Action: Climb
# Sequence 253: Predicted Action: Climb
# Sequence 254: Predicted Action: Climb
# Sequence 255: Predicted Action: Climb
# Sequence 256: Predicted Action: Climb
# Sequence 257: Predicted Action: Climb
# Sequence 258: Predicted Action: Climb
# Sequence 259: Predicted Action: Climb
# Sequence 260: Predicted Action: Climb
# Sequence 261: Predicted Action: Climb
# Sequence 262: Predicted Action: Climb
# Sequence 263: Predicted Action: Climb
# Sequence 264: Predicted Action: Climb
# Sequence 265: Predicted Action: Climb
# Sequence 266: Predicted Action: Climb
# Sequence 267: Predicted Action: Climb
# Sequence 268: Predicted Action: Climb
# Sequence 269: Predicted Action: Climb
# Sequence 270: Predicted Action: Climb
# Sequence 271: Predicted Action: Climb
# Sequence 272: Predicted Action: Climb
# Sequence 273: Predicted Action: Climb
# Sequence 274: Predicted Action: Climb
# Sequence 275: Predicted Action: Climb
# Sequence 276: Predicted Action: Climb
# Sequence 277: Predicted Action: Climb
# Sequence 278: Predicted Action: Climb
# Sequence 279: Predicted Action: Climb
# Sequence 280: Predicted Action: Climb
# Sequence 281: Predicted Action: Climb
# Sequence 282: Predicted Action: Climb
# Sequence 283: Predicted Action: Climb
# Sequence 284: Predicted Action: Climb
# Sequence 285: Predicted Action: Climb
# Sequence 286: Predicted Action: Climb
# Sequence 287: Predicted Action: Climb
# Sequence 288: Predicted Action: Climb
# Sequence 289: Predicted Action: Climb
# Sequence 290: Predicted Action: Climb
# Sequence 291: Predicted Action: Climb
# Sequence 292: Predicted Action: Climb
# Sequence 293: Predicted Action: Climb
# Sequence 294: Predicted Action: Climb
# Sequence 295: Predicted Action: Climb
# Sequence 296: Predicted Action: Climb
# Sequence 297: Predicted Action: Climb
# Sequence 298: Predicted Action: Climb
# Sequence 299: Predicted Action: Climb
# Sequence 300: Predicted Action: Climb
# Sequence 301: Predicted Action: Climb
# Sequence 302: Predicted Action: Climb
# Sequence 303: Predicted Action: Climb
# Sequence 304: Predicted Action: Climb
# Sequence 305: Predicted Action: Climb
# Sequence 306: Predicted Action: Climb
# Sequence 307: Predicted Action: Climb
# Sequence 308: Predicted Action: Climb
# Sequence 309: Predicted Action: Climb
# Sequence 310: Predicted Action: Climb
# Sequence 311: Predicted Action: Climb
# Sequence 312: Predicted Action: Climb
# Sequence 313: Predicted Action: Climb
# Sequence 314: Predicted Action: Climb
# Sequence 315: Predicted Action: Climb
# Sequence 316: Predicted Action: Climb
# Sequence 317: Predicted Action: Climb
# Sequence 318: Predicted Action: Climb
# Sequence 319: Predicted Action: Climb
# Sequence 320: Predicted Action: Climb
# Sequence 321: Predicted Action: Climb
# Sequence 322: Predicted Action: Climb
# Sequence 323: Predicted Action: Climb
# Sequence 324: Predicted Action: Climb
# Sequence 325: Predicted Action: Climb
# Sequence 326: Predicted Action: Climb
# Sequence 327: Predicted Action: Climb
# Sequence 328: Predicted Action: Climb
# Sequence 329: Predicted Action: Climb
# Sequence 330: Predicted Action: Climb
# Sequence 331: Predicted Action: Climb
# Sequence 332: Predicted Action: Climb
# Sequence 333: Predicted Action: Climb
# Sequence 334: Predicted Action: Climb
# Sequence 335: Predicted Action: Climb
# Sequence 336: Predicted Action: Climb
# Sequence 337: Predicted Action: Climb
# Sequence 338: Predicted Action: Climb
# Sequence 339: Predicted Action: Climb
# Sequence 340: Predicted Action: Climb
# Sequence 341: Predicted Action: Climb
# Sequence 342: Predicted Action: Climb
# Sequence 343: Predicted Action: Climb
# Sequence 344: Predicted Action: Climb
# Sequence 345: Predicted Action: Climb
# Sequence 346: Predicted Action: Climb
# Sequence 347: Predicted Action: Climb
# Sequence 348: Predicted Action: Climb
# Sequence 349: Predicted Action: Climb
# Sequence 350: Predicted Action: Climb
# Sequence 351: Predicted Action: Climb
# Sequence 352: Predicted Action: Climb
# Sequence 353: Predicted Action: Climb
# Sequence 354: Predicted Action: Climb
# Sequence 355: Predicted Action: Climb
# Sequence 356: Predicted Action: Climb
# Sequence 357: Predicted Action: Climb
# Sequence 358: Predicted Action: Climb
# Sequence 359: Predicted Action: Climb
# Sequence 360: Predicted Action: Climb
# Sequence 361: Predicted Action: Climb
# Sequence 362: Predicted Action: Climb
# Sequence 363: Predicted Action: Climb
# Sequence 364: Predicted Action: Climb
# Sequence 365: Predicted Action: Climb
# Sequence 366: Predicted Action: Climb
# Sequence 367: Predicted Action: Climb
# Sequence 368: Predicted Action: Climb
# Sequence 369: Predicted Action: Climb
# Sequence 370: Predicted Action: Climb
# Sequence 371: Predicted Action: Climb
# Sequence 372: Predicted Action: Climb
# Sequence 373: Predicted Action: Climb
# Sequence 374: Predicted Action: Climb
# Sequence 375: Predicted Action: Climb
# Sequence 376: Predicted Action: Climb
# Sequence 377: Predicted Action: Climb
# Sequence 378: Predicted Action: Climb
# Sequence 379: Predicted Action: Climb
# Sequence 380: Predicted Action: Climb
# Sequence 381: Predicted Action: Climb
# Sequence 382: Predicted Action: Climb
# Sequence 383: Predicted Action: Climb
# Sequence 384: Predicted Action: Climb
# Sequence 385: Predicted Action: Climb
# Sequence 386: Predicted Action: Climb
# Sequence 387: Predicted Action: Climb
# Sequence 388: Predicted Action: Climb
# Sequence 389: Predicted Action: Climb
# Sequence 390: Predicted Action: Climb
# Sequence 391: Predicted Action: Climb
# Sequence 392: Predicted Action: Climb
# Sequence 393: Predicted Action: Climb
# Sequence 394: Predicted Action: Climb
# Sequence 395: Predicted Action: Climb
# Sequence 396: Predicted Action: Climb
# Sequence 397: Predicted Action: Climb
# Sequence 398: Predicted Action: Climb
# Sequence 399: Predicted Action: Climb
# Sequence 400: Predicted Action: Climb
# Sequence 401: Predicted Action: Climb
# Sequence 402: Predicted Action: Climb
# Sequence 403: Predicted Action: Climb
# Sequence 404: Predicted Action: Climb
# Sequence 405: Predicted Action: Climb
# Sequence 406: Predicted Action: Climb
# Sequence 407: Predicted Action: Climb
# Sequence 408: Predicted Action: Climb
# Sequence 409: Predicted Action: Climb
# Sequence 410: Predicted Action: Climb
# Sequence 411: Predicted Action: Climb
# Sequence 412: Predicted Action: Climb
# Sequence 413: Predicted Action: Climb
# Sequence 414: Predicted Action: Climb
# Sequence 415: Predicted Action: Climb
# Sequence 416: Predicted Action: Climb
# Sequence 417: Predicted Action: Climb
# Sequence 418: Predicted Action: Climb
# Sequence 419: Predicted Action: Climb
# Sequence 420: Predicted Action: Climb
# Sequence 421: Predicted Action: Climb
# Sequence 422: Predicted Action: Climb
# Sequence 423: Predicted Action: Climb
# Sequence 424: Predicted Action: Climb
# Sequence 425: Predicted Action: Climb
# Sequence 426: Predicted Action: Climb
# Sequence 427: Predicted Action: Climb
# Sequence 428: Predicted Action: Climb
# Sequence 429: Predicted Action: Climb
# Sequence 430: Predicted Action: Climb
# Sequence 431: Predicted Action: Climb
# Sequence 432: Predicted Action: Climb
# Sequence 433: Predicted Action: Climb
# Sequence 434: Predicted Action: Climb
# Sequence 435: Predicted Action: Climb
# Sequence 436: Predicted Action: Climb
# Sequence 437: Predicted Action: Climb
# Sequence 438: Predicted Action: Climb
# Sequence 439: Predicted Action: Climb
# Sequence 440: Predicted Action: Climb
# Sequence 441: Predicted Action: Climb
# Sequence 442: Predicted Action: Climb
# Sequence 443: Predicted Action: Climb
# Sequence 444: Predicted Action: Climb
# Sequence 445: Predicted Action: Climb
# Sequence 446: Predicted Action: Climb
# Sequence 447: Predicted Action: Climb
# Sequence 448: Predicted Action: Climb
# Sequence 449: Predicted Action: Climb
# Sequence 450: Predicted Action: Climb
# Sequence 451: Predicted Action: Climb
# Sequence 452: Predicted Action: Climb
# Sequence 453: Predicted Action: Climb
# Sequence 454: Predicted Action: Climb
# Sequence 455: Predicted Action: Climb
# Sequence 456: Predicted Action: Climb
# Sequence 457: Predicted Action: Climb
# Sequence 458: Predicted Action: Climb
# Sequence 459: Predicted Action: Climb
# Sequence 460: Predicted Action: Climb
# Sequence 461: Predicted Action: Climb
# Sequence 462: Predicted Action: Climb
# Sequence 463: Predicted Action: Climb
# Sequence 464: Predicted Action: Jump
# Sequence 465: Predicted Action: Jump
# Sequence 466: Predicted Action: Jump
# Sequence 467: Predicted Action: Jump
# Sequence 468: Predicted Action: Jump
# Sequence 469: Predicted Action: Jump
# Sequence 470: Predicted Action: Jump
# Sequence 471: Predicted Action: Jump
# Sequence 472: Predicted Action: Jump
# Sequence 473: Predicted Action: Jump
# Sequence 474: Predicted Action: Jump
# Sequence 475: Predicted Action: Jump
# Sequence 476: Predicted Action: Jump
# Sequence 477: Predicted Action: Jump
# Sequence 478: Predicted Action: Jump
# Sequence 479: Predicted Action: Jump
# Sequence 480: Predicted Action: Jump
# Sequence 481: Predicted Action: Jump
# Sequence 482: Predicted Action: Jump
# Sequence 483: Predicted Action: Jump
# Sequence 484: Predicted Action: Jump
# Sequence 485: Predicted Action: Jump
# Sequence 486: Predicted Action: Jump
# Sequence 487: Predicted Action: Jump
# Sequence 488: Predicted Action: Jump
# Sequence 489: Predicted Action: Jump
# Sequence 490: Predicted Action: Jump
# Sequence 491: Predicted Action: Jump
# Sequence 492: Predicted Action: Jump
# Sequence 493: Predicted Action: Jump
# Sequence 494: Predicted Action: Jump
# Sequence 495: Predicted Action: Jump
# Sequence 496: Predicted Action: Jump
# Sequence 497: Predicted Action: Jump
# Sequence 498: Predicted Action: Jump
# Sequence 499: Predicted Action: Jump
# Sequence 500: Predicted Action: Jump
# Sequence 501: Predicted Action: Jump
# Sequence 502: Predicted Action: Jump
# Sequence 503: Predicted Action: Jump
# Sequence 504: Predicted Action: Jump
# Sequence 505: Predicted Action: Jump
# Sequence 506: Predicted Action: Jump
# Sequence 507: Predicted Action: Jump
# Sequence 508: Predicted Action: Jump
# Sequence 509: Predicted Action: Jump
# Sequence 510: Predicted Action: Jump
# Sequence 511: Predicted Action: Jump
# Sequence 512: Predicted Action: Jump
# Sequence 513: Predicted Action: Jump
# Sequence 514: Predicted Action: Jump
# Sequence 515: Predicted Action: Jump
# Sequence 516: Predicted Action: Jump
# Sequence 517: Predicted Action: Jump
# Sequence 518: Predicted Action: Jump
# Sequence 519: Predicted Action: Jump
# Sequence 520: Predicted Action: Jump
# Sequence 521: Predicted Action: Jump
# Sequence 522: Predicted Action: Jump
# Sequence 523: Predicted Action: Jump
# Sequence 524: Predicted Action: Jump
# Sequence 525: Predicted Action: Jump
# Sequence 526: Predicted Action: Jump
# Sequence 527: Predicted Action: Jump
# Sequence 528: Predicted Action: Jump
# Sequence 529: Predicted Action: Jump
# Sequence 530: Predicted Action: Jump
# Sequence 531: Predicted Action: Jump
# Sequence 532: Predicted Action: Jump
# Sequence 533: Predicted Action: Jump
# Sequence 534: Predicted Action: Jump
# Sequence 535: Predicted Action: Jump
# Sequence 536: Predicted Action: Jump
# Sequence 537: Predicted Action: Jump
# Sequence 538: Predicted Action: Jump
# Sequence 539: Predicted Action: Jump
# Sequence 540: Predicted Action: Jump
# Sequence 541: Predicted Action: Jump
# Sequence 542: Predicted Action: Jump
# Sequence 543: Predicted Action: Jump
# Sequence 544: Predicted Action: Jump
# Sequence 545: Predicted Action: Jump
# Sequence 546: Predicted Action: Jump
# Sequence 547: Predicted Action: Jump
# Sequence 548: Predicted Action: Jump
# Sequence 549: Predicted Action: Jump
# Sequence 550: Predicted Action: Jump
# Sequence 551: Predicted Action: Jump
# Sequence 552: Predicted Action: Jump
# Sequence 553: Predicted Action: Jump
# Sequence 554: Predicted Action: Jump
# Sequence 555: Predicted Action: Jump
# Sequence 556: Predicted Action: Jump
# Sequence 557: Predicted Action: Jump
# Sequence 558: Predicted Action: Jump
# Sequence 559: Predicted Action: Jump
# Sequence 560: Predicted Action: Jump
# Sequence 561: Predicted Action: Jump
# Sequence 562: Predicted Action: Jump
# Sequence 563: Predicted Action: Jump
# Sequence 564: Predicted Action: Jump
# Sequence 565: Predicted Action: Jump
# Sequence 566: Predicted Action: Jump
# Sequence 567: Predicted Action: Jump
# Sequence 568: Predicted Action: Jump
# Sequence 569: Predicted Action: Jump
# Sequence 570: Predicted Action: Jump
# Sequence 571: Predicted Action: Jump
# Sequence 572: Predicted Action: Jump
# Sequence 573: Predicted Action: Jump
# Sequence 574: Predicted Action: Jump
# Sequence 575: Predicted Action: Jump
# Sequence 576: Predicted Action: Jump
# Sequence 577: Predicted Action: Jump
# Sequence 578: Predicted Action: Jump
# Sequence 579: Predicted Action: Jump
# Sequence 580: Predicted Action: Jump
# Sequence 581: Predicted Action: Jump
# Sequence 582: Predicted Action: Jump
# Sequence 583: Predicted Action: Jump
# Sequence 584: Predicted Action: Jump
# Sequence 585: Predicted Action: Jump
# Sequence 586: Predicted Action: Jump
# Sequence 587: Predicted Action: Jump
# Sequence 588: Predicted Action: Jump
# Sequence 589: Predicted Action: Jump
# Sequence 590: Predicted Action: Jump
# Sequence 591: Predicted Action: Jump
# Sequence 592: Predicted Action: Jump
# Sequence 593: Predicted Action: Jump
# Sequence 594: Predicted Action: Jump
# Sequence 595: Predicted Action: Jump
# Sequence 596: Predicted Action: Jump
# Sequence 597: Predicted Action: Jump
# Sequence 598: Predicted Action: Jump
# Sequence 599: Predicted Action: Jump
# Sequence 600: Predicted Action: Jump
# Sequence 601: Predicted Action: Jump
# Sequence 602: Predicted Action: Jump
# Sequence 603: Predicted Action: Jump
# Sequence 604: Predicted Action: Jump
# Sequence 605: Predicted Action: Jump
# Sequence 606: Predicted Action: Jump
# Sequence 607: Predicted Action: Jump
# Sequence 608: Predicted Action: Jump
# Sequence 609: Predicted Action: Jump
# Sequence 610: Predicted Action: Jump
# Sequence 611: Predicted Action: Jump
# Sequence 612: Predicted Action: Jump
# Sequence 613: Predicted Action: Jump
# Sequence 614: Predicted Action: Jump
